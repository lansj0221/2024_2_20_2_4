# %%
import pandas as pd
import numpy as np
subjects = ['國文', '英文', '數學', '地理', '歷史']
scores = np.random.randint(50, 101, size=(50, 5))
scores_df = pd.DataFrame(scores, columns=subjects, index=range(1, 51))
scores_sum = scores_df.sum(axis=1)
scores_average = scores_df.mean(axis=1)
scores_df
# Out:
#      國文   英文  數學   地理   歷史
# 1    88   82  74   80   96
# 2    76  100  68   84   97
# 3    96   95  90   79   76
# 4    79   82  61   86   64
# 5    78   85  77   74   81
# 6    76   58  90   52   62
# 7    87  100  73   78   98
# 8    93   71  82   53   70
# 9    66   86  87   62   55
# 10   64   63  64   78   88
# 11   54  100  50   99   88
# 12   69   98  68   61  100
# 13   54   72  74   64   70
# 14   91   54  63   67   62
# 15   82   77  66   94   75
# 16   87   67  53   62   60
# 17   76   95  75   81   67
# 18   85   62  52   88   50
# 19  100   86  59   59   90
# 20   91   60  74   90   50
# 21   89   70  63   53  100
# 22   72   80  53   53   89
# 23   52   62  62   86   63
# 24   92   75  79   71   50
# 25   61   61  71   72   98
# 26   68   62  65   59   93
# 27   82   93  95  100   91
# 28   96   59  69   51   70
# 29   53   76  85   64   96
# 30   64   60  88   83   86
# 31   58   94  73   67   85
# 32   95   61  66   60   92
# 33   55   70  77   96   79
# 34   84   53  74   71   62
# 35   57   90  60   65   60
# 36   87   78  97   59   65
# 37   87   92  97   89   50
# 38   67   61  76   70   78
# 39   61   61  63   94   98
# 40   69   65  91   79   98
# 41   62   84  73   91   89
# 42   89   75  89  100   69
# 43   54   73  98   87   52
# 44   87   52  50   89   70
# 45   84   53  78  100   80
# 46   98   93  94   70   73
# 47   91   69  54   88   63
# 48   92   75  52   75   88
# 49   79   73  96   79   70
# 50   91   94  96   65   84

# %%
from pandas import Series
def to_statistic(value:Series)->Series:
    return Series([value.max(),value.min(),value.mean()],index=['最高分','最低分','平均分'])
scores_df.apply(to_statistic)
# Out:
#          國文      英文     數學      地理     歷史
# 最高分  100.00  100.00  98.00  100.00  100.0
# 最低分   52.00   52.00  50.00   51.00   50.0
# 平均分   77.36   75.14  73.68   75.54   76.8
